# %% [markdown]
# # Metode

# %% [markdown]
# ## Variable fra de fire kilder før datacleaning

# %%
import pandas as pd

# %%
df_compustat = pd.read_csv("/content/drive/MyDrive/Cand.fælles/Speciale/Nøgetal/Compustat_permincl.csv.zip")

# %%
df_actuals = pd.read_csv("/content/drive/MyDrive/Cand.fælles/Speciale/Acutal data/actual_longrun_falseindex.csv")

# %%
df_actuals.drop(columns=["Selling General & Administrative Expenses - Total","1 Month Total Return"],inplace=True)

# %%
df_aktie_data = pd.read_csv("/content/drive/MyDrive/Cand.fælles/Speciale/aktie_data_for_merging.csv")

# %%
analytiker_data = pd.read_csv("/content/drive/MyDrive/Cand.fælles/Speciale/Analyst data/analyst_Q1_longrun_falseindex.csv")

# %%
fama_return = pd.read_csv("/content/drive/MyDrive/Cand.fælles/Speciale/Fama French/returns_industry.csv",sep=";")

# %%
fama_return.rename(columns={"Unnamed: 0": "Date"},inplace=True)

# %%
Variables = pd.DataFrame([df_compustat.columns,df_actuals.columns,analytiker_data,df_aktie_data,fama_return],index=["Compustat","IBES Actuals", "IBES summary","CRSP","Fama French"]).T

# %%
Variables.replace({None: ""},inplace=True)

# %%
Variables.to_excel("variables.xlsx",index=False)

# %% [markdown]
# ## De endelige hyperparametre

# %%
! pip install optuna

# %%
import joblib

# %%
study = joblib.load("/content/drive/MyDrive/Cand.fælles/Speciale/Python/hyperparametertuning_study.pkl")

# %%
study.best_params

# %% [markdown]
# # Analyse

# %% [markdown]
# ## Uden Healthcare RMSE

# %%
uden_health = joblib.load("/content/drive/MyDrive/Cand.fælles/Speciale/Python/performance_marketcap_udenhealthcare.pkl")

# %%
uden_health.to_excel("health.xlsx")

# %%
uden_health
