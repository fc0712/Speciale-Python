# %%
import pandas as pd

# %%
compu = pd.read_csv("/content/drive/MyDrive/Cand.fælles/Speciale/Nøgetal/Compustat_nøgletal.zip")

# %%
compu.info()

# %%
compu[compu.cusip =="037833100"]

# %%
gvperm = pd.read_csv("/content/drive/MyDrive/Cand.fælles/Speciale/Nøgetal/gvkeyperm.csv")

# %%
gvperm.info()

# %%
gvperm = gvperm[["gvkey","LPERMNO","LPERMCO"]]

# %%
gvperm

# %%
 dict_perm = dict(zip(gvperm.gvkey,gvperm.LPERMNO))

# %%
pd.Series(gvperm.LPERMNO, index=gvperm.gvkey)

# %%
compu[compu.GVKEY ==54594]

# %%
crsp = pd.read_csv("/content/drive/MyDrive/Cand.fælles/Speciale/aktie_månedlig.zip")

# %%
crsp

# %%
crsp[crsp.PERMNO==54594]

# %%
compu[compu.conm.str.contains("APPLE")]

# %%
gvperm[gvperm.gvkey ==1690]

# %%
crsp[crsp.PERMNO ==10082]

# %%
compu["perm"] = compu.GVKEY.map(dict_perm)

# %%
compu

# %%
compu.to_csv("/content/drive/MyDrive/Cand.fælles/Speciale/Nøgetal/Compustat_permincl.csv.zip",compression="zip",index=False)

# %%
pd.read_csv("/content/drive/MyDrive/Cand.fælles/Speciale/Nøgetal/Compustat_permincl.csv.zip").info()
